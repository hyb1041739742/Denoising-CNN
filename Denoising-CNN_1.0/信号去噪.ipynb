# %% [markdown]
# # DnCNN UDnCNN DUDnCNN

# %% [markdown]
# ## 1. 准备工作

# %%
dataset_root_dir = '../dataset'

# %%
# !wget -N https://raw.githubusercontent.com/eebowen/Transfer-Learning-and-Deep-Neural-Network-Acceleration-for-Image-Classification/master/nntools.py

# %%
# %matplotlib inline
import os
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.utils.data as td
import torchvision as tv
from PIL import Image
import matplotlib.pyplot as plt
import nntools as nt
import time

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)
# Out:
# cuda

# %% [markdown]
# ## 2. 载入训练集

# %% [markdown]
# $σ = 30$ 高斯噪音 $180 × 180$ 裁剪（左上角或随机位置）

# %%
class NoisyBSDSDataset(td.Dataset):

    def __init__(self, root_dir, mode='train', image_size=(40, 50), sigma=30):
        super(NoisyBSDSDataset, self).__init__()
        self.mode = mode
        self.image_size = image_size
        self.sigma = sigma
        self.images_dir = os.path.join(root_dir, mode)
        self.files = os.listdir(self.images_dir)
        self.noisy_images_dir = self.images_dir + '_noisy'
        self.noisy_files = os.listdir(self.noisy_images_dir)

    def __len__(self):
        return len(self.files)

    def __repr__(self):
        return "NoisyBSDSDataset(mode={}, image_size={}, sigma={})". \
            format(self.mode, self.image_size, self.sigma)

    def __getitem__(self, idx):
        img_path = os.path.join(self.images_dir, self.files[idx])
        noisy_img_path = os.path.join(self.noisy_images_dir, self.noisy_files[idx])
        clean = Image.open(img_path).convert('L').convert('RGB')
        noisy = Image.open(noisy_img_path).convert('L').convert('RGB')

        # 随机裁剪
        #i = np.random.randint(clean.size[0] - self.image_size[0])
        #j = np.random.randint(clean.size[1] - self.image_size[1])
        i=0
        j=0
        # clean = clean.crop([i, j, i+self.image_size[0], j+self.image_size[1]])
        # noisy = noisy.crop([i, j, i+self.image_size[0], j+self.image_size[1]])

        transform = tv.transforms.Compose([
            # 转换张量
            tv.transforms.ToTensor(),
            # [−1, 1]
            tv.transforms.Normalize((.5,.5,.5,), (.5,.5,.5,))
            ])
        clean = transform(clean)
        noisy = transform(noisy)
        # clean = clean.getdata(clean)
        # noisy = noisy.getdata(noisy)

        return noisy, clean

# %%
def myimshow(image, ax=plt):
    image = image.to('cpu').numpy()
    image = np.moveaxis(image, [0, 1, 2], [2, 0, 1])
    image = (image + 1) / 2
    image[image < 0] = 0
    image[image > 1] = 1
    h = ax.imshow(image)
    ax.axis('off')
    return h

# %% [markdown]
# #### 导训练集和测试集进来

# %%
train_set = NoisyBSDSDataset(dataset_root_dir)
test_set = NoisyBSDSDataset(dataset_root_dir, mode='test')

# %%
x = test_set[0]
fig, axes = plt.subplots(ncols=2)
myimshow(x[0], ax=axes[0])
axes[0].set_title('Noisy')
myimshow(x[1], ax=axes[1])
axes[1].set_title('Clean')
print(f'image size is {x[0].shape}.')
# Out:
# image size is torch.Size([3, 40, 50]).

# %% [markdown]
# ## 3. DnCNN

# %% [markdown]
# #### loss 用的均方差

# %%
class NNRegressor(nt.NeuralNetwork):

    def __init__(self):
        super(NNRegressor, self).__init__()
        self.mse = nn.MSELoss()

    def criterion(self, y, d):
        return self.mse(y, d)

# %% [markdown]
# ### CNN 网络为啥要带个权重
#
# 看这个台湾人写的比较清楚
# [深度學習: Weight initialization和Batch Normalization](https://chih-sheng-huang821.medium.com/%E6%B7%B1%E5%BA%A6%E5%AD%B8%E7%BF%92-weight-initialization%E5%92%8Cbatch-normalization-f264c4be37f5)

# %% [markdown]
# #### 无权初始化

# %%
class DnCNN(NNRegressor):

    def __init__(self, D, C=64):
        super(DnCNN, self).__init__()
        self.D = D
        
        self.conv = nn.ModuleList()
        self.conv.append(nn.Conv2d(3, C, 3, padding=1))
        self.conv.extend([nn.Conv2d(C, C, 3, padding=1) for _ in range(D)])
        self.conv.append(nn.Conv2d(C, 3, 3, padding=1))
        
        self.bn = nn.ModuleList()
        for k in range(D):
            self.bn.append(nn.BatchNorm2d(C, C))

    def forward(self, x):
        D = self.D
        h = F.relu(self.conv[0](x))
        for i in range(D):
            h = F.relu(self.bn[i](self.conv[i+1](h)))
        y = self.conv[D+1](h) + x
        return y

# %% [markdown]
# 零填充（泛卷积）对输入图像矩阵的边缘进行滤波，是玄学

# %%
x, _ = train_set[-1]
x = x.unsqueeze(0).to(device)
Ds = [0, 1, 2, 4, 8]

fig, axes = plt.subplots(nrows=len(Ds), ncols=3, figsize=(9,9))
for i in range(len(Ds)):
    with torch.no_grad():
        model = DnCNN(Ds[i]).to(device)
        y = model.forward(x) # 4-d
    # 3-d
    myimshow(x[0], ax=axes[i][0])
    axes[i][0].set_title('x[0]')
    myimshow(y[0], ax=axes[i][1])
    axes[i][1].set_title(f'y[0] (D={Ds[i]})')
    myimshow(x[0]-y[0], ax=axes[i][2])
    axes[i][2].set_title(f'x[0]-y[0] (D={Ds[i]})')

# %% [markdown]
# D=0 才有残差输出，梯度消失，没法炼丹

# %% [markdown]
# #### 带权跑一下

# %%
class DnCNN(NNRegressor):

    def __init__(self, D, C=64):
        super(DnCNN, self).__init__()
        self.D = D
        
        self.conv = nn.ModuleList()
        self.conv.append(nn.Conv2d(3, C, 3, padding=1))
        self.conv.extend([nn.Conv2d(C, C, 3, padding=1) for _ in range(D)])
        self.conv.append(nn.Conv2d(C, 3, 3, padding=1))

        # Kaiming正态分布初始化，又叫啥He('s) initialization
        for i in range(len(self.conv[:-1])):
            nn.init.kaiming_normal_(self.conv[i].weight.data, nonlinearity='leaky_relu')
        
        self.bn = nn.ModuleList()
        for k in range(D):
            self.bn.append(nn.BatchNorm2d(C, C))
        for i in range(len(self.bn[:-1])):
            nn.init.constant_(self.bn[i].weight.data, 1.25 * np.sqrt(C))  

    def forward(self, x):
        D = self.D
        h = F.relu(self.conv[0](x))
        for i in range(D):
            h = F.relu(self.bn[i](self.conv[i+1](h)))
        y = self.conv[D+1](h) + x
        return y

# %%
x, _ = train_set[-1]
x = x.unsqueeze(0).to(device)
Ds = [0, 1, 2, 4, 8]

fig, axes = plt.subplots(nrows=len(Ds), ncols=3, figsize=(9,9))
for i in range(len(Ds)):
    with torch.no_grad():
        model = DnCNN(Ds[i]).to(device)
        y = model.forward(x)
    
    myimshow(x[0], ax=axes[i][0])
    axes[i][0].set_title('x[0]')
    myimshow(y[0], ax=axes[i][1])
    axes[i][1].set_title(f'y[0] (D={Ds[i]})')
    myimshow(x[0]-y[0], ax=axes[i][2])
    axes[i][2].set_title(f'x[0]-y[0] (D={Ds[i]})')

# %% [markdown]
# 然后残差就非零，能梯度下降，能炼丹

# %% [markdown]
# ### PSNR
#
# 峰值信噪比 PSNR (Peak Signal-to-Noise-Ratio)，值域是 `[−1, 1]`
# $$
# PSNR = 10\log_{10}\frac{4n}{\Vert y-d\Vert_2^2}
# $$
#
# `d` 是理想值， `y` 是估计值，分母就是均方差， `n` 是张量大小，对数定义，单位是 `dB`，数越大越好

# %% [markdown]
# #### 这东西是要算平均的

# %%
class DenoisingStatsManager(nt.StatsManager):

    def __init__(self):
        super(DenoisingStatsManager, self).__init__()

    def init(self):
        super(DenoisingStatsManager, self).init()
        self.running_psnr = 0

    def accumulate(self, loss, x, y, d):
        super(DenoisingStatsManager, self).accumulate(loss, x, y, d)    
        n = x.shape[0] * x.shape[1] * x.shape[2] * x.shape[3]
        self.running_psnr += 10*torch.log10(4*n/(torch.norm(y-d)**2))

    def summarize(self):
        loss = super(DenoisingStatsManager, self).summarize()
        psnr = self.running_psnr / self.number_update
        return {'loss': loss, 'PSNR': psnr.cpu()}

# %%
def plot(exp, fig, axes, noisy, visu_rate=2):
    if exp.epoch % visu_rate != 0:
        return
    with torch.no_grad():
        denoised = exp.net(noisy[None].to(net.device))[0]
    axes[0][0].clear()
    axes[0][1].clear()
    axes[1][0].clear()
    axes[1][1].clear()
    myimshow(noisy, ax=axes[0][0])
    axes[0][0].set_title('Noisy image')
    
    myimshow(denoised, ax=axes[0][1])
    axes[0][1].set_title('Denoised image')
    
    axes[1][0].plot([exp.history[k][0]['loss'] for k in range(exp.epoch)], label='training loss')
    axes[1][0].set_ylabel('Loss')
    axes[1][0].set_xlabel('Epoch')
    axes[1][0].legend()
    
    axes[1][1].plot([exp.history[k][0]['PSNR'] for k in range(exp.epoch)], label='training psnr')
    axes[1][1].set_ylabel('PSNR')
    axes[1][1].set_xlabel('Epoch')
    axes[1][1].legend()
    
    plt.tight_layout()
    fig.canvas.draw()

# %% [markdown]
# ### `DnCNN` 炼丹

# %%
lr = 1e-3
net = DnCNN(6).to(device)
adam = torch.optim.Adam(net.parameters(), lr=lr)
stats_manager = DenoisingStatsManager()
exp1 = nt.Experiment(net, train_set, test_set, adam, stats_manager, batch_size=10, 
               output_dir="./checkpoints/denoising1", perform_validation_during_training=True)

# %%
fig, axes = plt.subplots(ncols=2, nrows=2, figsize=(9, 7))
exp1.run(num_epochs=200, plot=lambda exp: plot(exp, fig=fig, axes=axes,
                                                noisy=test_set[0][0]))
# Out:
# Start/Continue training from epoch 0
# Epoch 1 (Time: 4.35s) (loss: {'loss': 0.0896022841334343, 'PSNR': tensor(16.4974)})
# Epoch 2 (Time: 2.76s) (loss: {'loss': 0.04261833429336548, 'PSNR': tensor(19.7246)})
# Epoch 3 (Time: 3.49s) (loss: {'loss': 0.027868233621120453, 'PSNR': tensor(21.5695)})
# Epoch 4 (Time: 2.52s) (loss: {'loss': 0.025465894490480423, 'PSNR': tensor(21.9610)})
# Epoch 5 (Time: 2.34s) (loss: {'loss': 0.02160167321562767, 'PSNR': tensor(22.6757)})
# Epoch 6 (Time: 1.87s) (loss: {'loss': 0.0192940142005682, 'PSNR': tensor(23.1664)})
# Epoch 7 (Time: 2.20s) (loss: {'loss': 0.017289357259869576, 'PSNR': tensor(23.6428)})
# Epoch 8 (Time: 1.83s) (loss: {'loss': 0.017052805051207542, 'PSNR': tensor(23.7026)})
# Epoch 9 (Time: 1.41s) (loss: {'loss': 0.016057493165135384, 'PSNR': tensor(23.9638)})
# Epoch 10 (Time: 1.38s) (loss: {'loss': 0.015077512711286545, 'PSNR': tensor(24.2373)})
# Epoch 11 (Time: 1.37s) (loss: {'loss': 0.01407890859991312, 'PSNR': tensor(24.5349)})
# Epoch 12 (Time: 1.34s) (loss: {'loss': 0.013592871837317944, 'PSNR': tensor(24.6875)})
# Epoch 13 (Time: 1.37s) (loss: {'loss': 0.013609882444143295, 'PSNR': tensor(24.6821)})
# Epoch 14 (Time: 1.29s) (loss: {'loss': 0.01539919339120388, 'PSNR': tensor(24.1456)})
# Epoch 15 (Time: 1.24s) (loss: {'loss': 0.013124799355864525, 'PSNR': tensor(24.8397)})
# Epoch 16 (Time: 1.24s) (loss: {'loss': 0.012788002379238605, 'PSNR': tensor(24.9526)})
# Epoch 17 (Time: 1.24s) (loss: {'loss': 0.012741909362375736, 'PSNR': tensor(24.9683)})
# Epoch 18 (Time: 1.24s) (loss: {'loss': 0.012936342507600784, 'PSNR': tensor(24.9025)})
# Epoch 19 (Time: 1.32s) (loss: {'loss': 0.01260693371295929, 'PSNR': tensor(25.0145)})
# Epoch 20 (Time: 1.32s) (loss: {'loss': 0.01230448018759489, 'PSNR': tensor(25.1200)})
# Epoch 21 (Time: 1.41s) (loss: {'loss': 0.012264136224985123, 'PSNR': tensor(25.1342)})
# Epoch 22 (Time: 1.37s) (loss: {'loss': 0.012139376252889633, 'PSNR': tensor(25.1786)})
# Epoch 23 (Time: 1.30s) (loss: {'loss': 0.011078962124884129, 'PSNR': tensor(25.5756)})
# Epoch 24 (Time: 1.26s) (loss: {'loss': 0.012035857886075974, 'PSNR': tensor(25.2158)})
# Epoch 25 (Time: 1.37s) (loss: {'loss': 0.012154710479080677, 'PSNR': tensor(25.1732)})
# Epoch 26 (Time: 1.35s) (loss: {'loss': 0.012454467825591564, 'PSNR': tensor(25.0673)})
# Epoch 27 (Time: 1.23s) (loss: {'loss': 0.010957502759993076, 'PSNR': tensor(25.6235)})
# Epoch 28 (Time: 1.26s) (loss: {'loss': 0.012281246483325958, 'PSNR': tensor(25.1282)})
# Epoch 29 (Time: 1.25s) (loss: {'loss': 0.011925404891371727, 'PSNR': tensor(25.2559)})
# Epoch 30 (Time: 1.25s) (loss: {'loss': 0.012375577352941036, 'PSNR': tensor(25.0949)})
# Epoch 31 (Time: 1.27s) (loss: {'loss': 0.012195575051009655, 'PSNR': tensor(25.1586)})
# Epoch 32 (Time: 1.30s) (loss: {'loss': 0.012005597352981567, 'PSNR': tensor(25.2268)})
# Epoch 33 (Time: 1.30s) (loss: {'loss': 0.012054991908371449, 'PSNR': tensor(25.2089)})
# Epoch 34 (Time: 1.25s) (loss: {'loss': 0.011900144629180431, 'PSNR': tensor(25.2651)})
# Epoch 35 (Time: 1.26s) (loss: {'loss': 0.011757939122617245, 'PSNR': tensor(25.3173)})
# Epoch 36 (Time: 1.29s) (loss: {'loss': 0.011574801057577133, 'PSNR': tensor(25.3855)})
# Epoch 37 (Time: 1.30s) (loss: {'loss': 0.011356990784406662, 'PSNR': tensor(25.4680)})
# Epoch 38 (Time: 1.34s) (loss: {'loss': 0.011120546609163284, 'PSNR': tensor(25.5593)})
# Epoch 39 (Time: 1.29s) (loss: {'loss': 0.012147395871579647, 'PSNR': tensor(25.1758)})
# Epoch 40 (Time: 1.28s) (loss: {'loss': 0.011907675303518772, 'PSNR': tensor(25.2623)})
# Epoch 41 (Time: 1.24s) (loss: {'loss': 0.012229083105921745, 'PSNR': tensor(25.1467)})
# Epoch 42 (Time: 1.26s) (loss: {'loss': 0.011353359557688236, 'PSNR': tensor(25.4694)})
# Epoch 43 (Time: 1.32s) (loss: {'loss': 0.01167228538542986, 'PSNR': tensor(25.3490)})
# Epoch 44 (Time: 1.36s) (loss: {'loss': 0.011449849233031273, 'PSNR': tensor(25.4326)})
# Epoch 45 (Time: 1.26s) (loss: {'loss': 0.011553576216101646, 'PSNR': tensor(25.3934)})
# Epoch 46 (Time: 1.34s) (loss: {'loss': 0.011808408424258232, 'PSNR': tensor(25.2987)})
# Epoch 47 (Time: 1.26s) (loss: {'loss': 0.011148321442306042, 'PSNR': tensor(25.5485)})
# Epoch 48 (Time: 1.24s) (loss: {'loss': 0.01245757844299078, 'PSNR': tensor(25.0663)})
# Epoch 49 (Time: 1.31s) (loss: {'loss': 0.011060132645070553, 'PSNR': tensor(25.5830)})
# Epoch 50 (Time: 1.27s) (loss: {'loss': 0.01172244269400835, 'PSNR': tensor(25.3304)})
# Epoch 51 (Time: 1.27s) (loss: {'loss': 0.011541482992470264, 'PSNR': tensor(25.3980)})
# Epoch 52 (Time: 1.28s) (loss: {'loss': 0.011283384636044502, 'PSNR': tensor(25.4962)})
# Epoch 53 (Time: 1.26s) (loss: {'loss': 0.011112833395600319, 'PSNR': tensor(25.5624)})
# Epoch 54 (Time: 1.32s) (loss: {'loss': 0.012119821272790432, 'PSNR': tensor(25.1856)})
# Epoch 55 (Time: 1.40s) (loss: {'loss': 0.010706032626330853, 'PSNR': tensor(25.7243)})
# Epoch 56 (Time: 1.32s) (loss: {'loss': 0.010962177067995071, 'PSNR': tensor(25.6216)})
# Epoch 57 (Time: 1.27s) (loss: {'loss': 0.01116723008453846, 'PSNR': tensor(25.5411)})
# Epoch 58 (Time: 1.25s) (loss: {'loss': 0.011118062771856785, 'PSNR': tensor(25.5603)})
# Epoch 59 (Time: 1.27s) (loss: {'loss': 0.010906827636063099, 'PSNR': tensor(25.6436)})
# Epoch 60 (Time: 1.30s) (loss: {'loss': 0.01206852588802576, 'PSNR': tensor(25.2041)})
# Epoch 61 (Time: 1.26s) (loss: {'loss': 0.011072253808379173, 'PSNR': tensor(25.5782)})
# Epoch 62 (Time: 1.31s) (loss: {'loss': 0.011094657704234123, 'PSNR': tensor(25.5695)})
# Epoch 63 (Time: 1.27s) (loss: {'loss': 0.011126444675028324, 'PSNR': tensor(25.5570)})
# Epoch 64 (Time: 1.28s) (loss: {'loss': 0.010856076143682003, 'PSNR': tensor(25.6639)})
# Epoch 65 (Time: 1.30s) (loss: {'loss': 0.011222009547054768, 'PSNR': tensor(25.5199)})
# Epoch 66 (Time: 1.27s) (loss: {'loss': 0.01093756128102541, 'PSNR': tensor(25.6314)})
# Epoch 67 (Time: 1.28s) (loss: {'loss': 0.012199299409985542, 'PSNR': tensor(25.1573)})
# Epoch 68 (Time: 1.34s) (loss: {'loss': 0.010694853030145168, 'PSNR': tensor(25.7289)})
# Epoch 69 (Time: 1.28s) (loss: {'loss': 0.01071284431964159, 'PSNR': tensor(25.7216)})
# Epoch 70 (Time: 1.32s) (loss: {'loss': 0.011209612712264061, 'PSNR': tensor(25.5247)})
# Epoch 71 (Time: 1.30s) (loss: {'loss': 0.01070916373282671, 'PSNR': tensor(25.7230)})
# Epoch 72 (Time: 1.31s) (loss: {'loss': 0.010725647211074829, 'PSNR': tensor(25.7164)})
# Epoch 73 (Time: 1.35s) (loss: {'loss': 0.011755932122468948, 'PSNR': tensor(25.3180)})
# Epoch 74 (Time: 1.30s) (loss: {'loss': 0.01154074352234602, 'PSNR': tensor(25.3983)})
# Epoch 75 (Time: 1.33s) (loss: {'loss': 0.01043613813817501, 'PSNR': tensor(25.8352)})
# Epoch 76 (Time: 1.34s) (loss: {'loss': 0.01055884175002575, 'PSNR': tensor(25.7844)})
# Epoch 77 (Time: 1.30s) (loss: {'loss': 0.010414202697575092, 'PSNR': tensor(25.8443)})
# Epoch 78 (Time: 1.39s) (loss: {'loss': 0.010890807956457138, 'PSNR': tensor(25.6500)})
# Epoch 79 (Time: 1.37s) (loss: {'loss': 0.010312837548553944, 'PSNR': tensor(25.8868)})
# Epoch 80 (Time: 1.29s) (loss: {'loss': 0.01252875104546547, 'PSNR': tensor(25.0415)})
# Epoch 81 (Time: 1.30s) (loss: {'loss': 0.010395299643278122, 'PSNR': tensor(25.8522)})
# Epoch 82 (Time: 1.32s) (loss: {'loss': 0.01070205308496952, 'PSNR': tensor(25.7259)})
# Epoch 83 (Time: 1.45s) (loss: {'loss': 0.010445049963891506, 'PSNR': tensor(25.8315)})
# Epoch 84 (Time: 1.34s) (loss: {'loss': 0.01019286923110485, 'PSNR': tensor(25.9376)})
# Epoch 85 (Time: 1.37s) (loss: {'loss': 0.01083849836140871, 'PSNR': tensor(25.6709)})
# Epoch 86 (Time: 1.42s) (loss: {'loss': 0.010701155290007591, 'PSNR': tensor(25.7263)})
# Epoch 87 (Time: 1.38s) (loss: {'loss': 0.010715092532336712, 'PSNR': tensor(25.7206)})
# Epoch 88 (Time: 1.36s) (loss: {'loss': 0.010689851827919483, 'PSNR': tensor(25.7309)})
# Epoch 89 (Time: 1.35s) (loss: {'loss': 0.01044093444943428, 'PSNR': tensor(25.8332)})
# Epoch 90 (Time: 1.29s) (loss: {'loss': 0.010626590810716152, 'PSNR': tensor(25.7567)})
# Epoch 91 (Time: 1.27s) (loss: {'loss': 0.011857672594487667, 'PSNR': tensor(25.2806)})
# Epoch 92 (Time: 1.29s) (loss: {'loss': 0.010863023810088634, 'PSNR': tensor(25.6611)})
# Epoch 93 (Time: 1.29s) (loss: {'loss': 0.011435567401349545, 'PSNR': tensor(25.4380)})
# Epoch 94 (Time: 1.33s) (loss: {'loss': 0.011182219721376896, 'PSNR': tensor(25.5353)})
# Epoch 95 (Time: 1.45s) (loss: {'loss': 0.010736912488937378, 'PSNR': tensor(25.7118)})
# Epoch 96 (Time: 1.43s) (loss: {'loss': 0.010800667107105255, 'PSNR': tensor(25.6861)})
# Epoch 97 (Time: 1.44s) (loss: {'loss': 0.011377709917724133, 'PSNR': tensor(25.4601)})
# Epoch 98 (Time: 1.50s) (loss: {'loss': 0.010806459933519363, 'PSNR': tensor(25.6838)})
# Epoch 99 (Time: 1.38s) (loss: {'loss': 0.01058019045740366, 'PSNR': tensor(25.7757)})
# Epoch 100 (Time: 1.36s) (loss: {'loss': 0.01049939263612032, 'PSNR': tensor(25.8090)})
# Epoch 101 (Time: 1.41s) (loss: {'loss': 0.010912732221186161, 'PSNR': tensor(25.6413)})
# Epoch 102 (Time: 1.43s) (loss: {'loss': 0.011005389504134655, 'PSNR': tensor(25.6045)})
# Epoch 103 (Time: 1.32s) (loss: {'loss': 0.010485561564564705, 'PSNR': tensor(25.8147)})
# Epoch 104 (Time: 1.37s) (loss: {'loss': 0.011016005650162697, 'PSNR': tensor(25.6004)})
# Epoch 105 (Time: 1.34s) (loss: {'loss': 0.010339559987187386, 'PSNR': tensor(25.8756)})
# Epoch 106 (Time: 1.29s) (loss: {'loss': 0.010660044848918915, 'PSNR': tensor(25.7430)})
# Epoch 107 (Time: 1.31s) (loss: {'loss': 0.010516130365431309, 'PSNR': tensor(25.8020)})
# Epoch 108 (Time: 1.32s) (loss: {'loss': 0.010393254458904266, 'PSNR': tensor(25.8531)})
# Epoch 109 (Time: 1.34s) (loss: {'loss': 0.010911645367741585, 'PSNR': tensor(25.6417)})
# Epoch 110 (Time: 1.31s) (loss: {'loss': 0.010238760150969028, 'PSNR': tensor(25.9181)})
# Epoch 111 (Time: 1.40s) (loss: {'loss': 0.010278742760419846, 'PSNR': tensor(25.9012)})
# Epoch 112 (Time: 1.39s) (loss: {'loss': 0.010753471404314041, 'PSNR': tensor(25.7051)})
# Epoch 113 (Time: 1.33s) (loss: {'loss': 0.010130401700735092, 'PSNR': tensor(25.9643)})
# Epoch 114 (Time: 1.34s) (loss: {'loss': 0.010038641281425953, 'PSNR': tensor(26.0039)})
# Epoch 115 (Time: 1.38s) (loss: {'loss': 0.010600907728075981, 'PSNR': tensor(25.7672)})
# Epoch 116 (Time: 1.31s) (loss: {'loss': 0.010957654565572739, 'PSNR': tensor(25.6234)})
# Epoch 117 (Time: 1.40s) (loss: {'loss': 0.010452890768647194, 'PSNR': tensor(25.8282)})
# Epoch 118 (Time: 1.33s) (loss: {'loss': 0.010957405902445316, 'PSNR': tensor(25.6235)})
# Epoch 119 (Time: 1.36s) (loss: {'loss': 0.010994158685207367, 'PSNR': tensor(25.6090)})
# Epoch 120 (Time: 1.42s) (loss: {'loss': 0.009925536811351776, 'PSNR': tensor(26.0531)})
# Epoch 121 (Time: 1.42s) (loss: {'loss': 0.010272656567394733, 'PSNR': tensor(25.9038)})
# Epoch 122 (Time: 1.42s) (loss: {'loss': 0.010452677495777607, 'PSNR': tensor(25.8283)})
# Epoch 123 (Time: 1.42s) (loss: {'loss': 0.010510229505598545, 'PSNR': tensor(25.8045)})
# Epoch 124 (Time: 1.39s) (loss: {'loss': 0.009677696973085403, 'PSNR': tensor(26.1629)})
# Epoch 125 (Time: 1.29s) (loss: {'loss': 0.00994723942130804, 'PSNR': tensor(26.0436)})
# Epoch 126 (Time: 1.27s) (loss: {'loss': 0.009831640869379044, 'PSNR': tensor(26.0943)})
# Epoch 127 (Time: 1.28s) (loss: {'loss': 0.011011747643351555, 'PSNR': tensor(25.6020)})
# Epoch 128 (Time: 1.32s) (loss: {'loss': 0.010250789113342762, 'PSNR': tensor(25.9130)})
# Epoch 129 (Time: 1.30s) (loss: {'loss': 0.010313778184354305, 'PSNR': tensor(25.8864)})
# Epoch 130 (Time: 1.29s) (loss: {'loss': 0.010532216168940067, 'PSNR': tensor(25.7954)})
# Epoch 131 (Time: 1.28s) (loss: {'loss': 0.01051696389913559, 'PSNR': tensor(25.8017)})
# Epoch 132 (Time: 1.27s) (loss: {'loss': 0.010236555710434914, 'PSNR': tensor(25.9191)})
# Epoch 133 (Time: 1.33s) (loss: {'loss': 0.010259680449962616, 'PSNR': tensor(25.9093)})
# Epoch 134 (Time: 1.30s) (loss: {'loss': 0.010998130775988102, 'PSNR': tensor(25.6074)})
# Epoch 135 (Time: 1.29s) (loss: {'loss': 0.010301628150045872, 'PSNR': tensor(25.8915)})
# Epoch 136 (Time: 1.30s) (loss: {'loss': 0.010445487685501575, 'PSNR': tensor(25.8313)})
# Epoch 137 (Time: 1.32s) (loss: {'loss': 0.010277840308845043, 'PSNR': tensor(25.9016)})
# Epoch 138 (Time: 1.43s) (loss: {'loss': 0.010104290209710598, 'PSNR': tensor(25.9755)})
# Epoch 139 (Time: 1.41s) (loss: {'loss': 0.010666029527783394, 'PSNR': tensor(25.7406)})
# Epoch 140 (Time: 1.43s) (loss: {'loss': 0.01067331526428461, 'PSNR': tensor(25.7376)})
# Epoch 141 (Time: 1.41s) (loss: {'loss': 0.011083520948886871, 'PSNR': tensor(25.5738)})
# Epoch 142 (Time: 1.43s) (loss: {'loss': 0.010520645417273045, 'PSNR': tensor(25.8002)})
# Epoch 143 (Time: 1.38s) (loss: {'loss': 0.010897912085056305, 'PSNR': tensor(25.6472)})
# Epoch 144 (Time: 1.41s) (loss: {'loss': 0.010631006211042404, 'PSNR': tensor(25.7549)})
# Epoch 145 (Time: 1.39s) (loss: {'loss': 0.009833868592977524, 'PSNR': tensor(26.0934)})
# Epoch 146 (Time: 1.38s) (loss: {'loss': 0.009758921340107918, 'PSNR': tensor(26.1266)})
# Epoch 147 (Time: 1.35s) (loss: {'loss': 0.00971048790961504, 'PSNR': tensor(26.1482)})
# Epoch 148 (Time: 1.42s) (loss: {'loss': 0.009898941963911057, 'PSNR': tensor(26.0647)})
# Epoch 149 (Time: 1.42s) (loss: {'loss': 0.009893984533846378, 'PSNR': tensor(26.0669)})
# Epoch 150 (Time: 1.36s) (loss: {'loss': 0.00995190255343914, 'PSNR': tensor(26.0415)})
# Epoch 151 (Time: 1.34s) (loss: {'loss': 0.010338152758777142, 'PSNR': tensor(25.8762)})
# Epoch 152 (Time: 1.35s) (loss: {'loss': 0.010330971330404282, 'PSNR': tensor(25.8792)})
# Epoch 153 (Time: 1.30s) (loss: {'loss': 0.009906015358865261, 'PSNR': tensor(26.0616)})
# Epoch 154 (Time: 1.36s) (loss: {'loss': 0.00965989101678133, 'PSNR': tensor(26.1709)})
# Epoch 155 (Time: 1.36s) (loss: {'loss': 0.010336578823626041, 'PSNR': tensor(25.8768)})
# Epoch 156 (Time: 1.29s) (loss: {'loss': 0.00995665229856968, 'PSNR': tensor(26.0395)})
# Epoch 157 (Time: 1.42s) (loss: {'loss': 0.010996367782354355, 'PSNR': tensor(25.6081)})
# Epoch 158 (Time: 1.48s) (loss: {'loss': 0.010209464468061924, 'PSNR': tensor(25.9306)})
# Epoch 159 (Time: 1.34s) (loss: {'loss': 0.009854063391685486, 'PSNR': tensor(26.0844)})
# Epoch 160 (Time: 1.31s) (loss: {'loss': 0.009705106727778912, 'PSNR': tensor(26.1506)})
# Epoch 161 (Time: 1.34s) (loss: {'loss': 0.010001804679632187, 'PSNR': tensor(26.0198)})
# Epoch 162 (Time: 1.33s) (loss: {'loss': 0.00988252554088831, 'PSNR': tensor(26.0719)})
# Epoch 163 (Time: 1.34s) (loss: {'loss': 0.009354982525110245, 'PSNR': tensor(26.3102)})
# Epoch 164 (Time: 1.34s) (loss: {'loss': 0.010441632941365242, 'PSNR': tensor(25.8329)})
# Epoch 165 (Time: 1.40s) (loss: {'loss': 0.009946808218955994, 'PSNR': tensor(26.0438)})
# Epoch 166 (Time: 1.35s) (loss: {'loss': 0.009874459356069565, 'PSNR': tensor(26.0755)})
# Epoch 167 (Time: 1.29s) (loss: {'loss': 0.009719369001686573, 'PSNR': tensor(26.1442)})
# Epoch 168 (Time: 1.30s) (loss: {'loss': 0.009994633495807648, 'PSNR': tensor(26.0229)})
# Epoch 169 (Time: 1.29s) (loss: {'loss': 0.010388118214905262, 'PSNR': tensor(25.8552)})
# Epoch 170 (Time: 1.29s) (loss: {'loss': 0.011327964253723621, 'PSNR': tensor(25.4791)})
# Epoch 171 (Time: 1.29s) (loss: {'loss': 0.009904185310006142, 'PSNR': tensor(26.0624)})
# Epoch 172 (Time: 1.26s) (loss: {'loss': 0.0098417978733778, 'PSNR': tensor(26.0899)})
# Epoch 173 (Time: 1.33s) (loss: {'loss': 0.011060811579227448, 'PSNR': tensor(25.5827)})
# Epoch 174 (Time: 1.28s) (loss: {'loss': 0.010041357949376106, 'PSNR': tensor(26.0027)})
# Epoch 175 (Time: 1.29s) (loss: {'loss': 0.009871847927570343, 'PSNR': tensor(26.0766)})
# Epoch 176 (Time: 1.29s) (loss: {'loss': 0.009299307130277157, 'PSNR': tensor(26.3361)})
# Epoch 177 (Time: 1.28s) (loss: {'loss': 0.010105828754603863, 'PSNR': tensor(25.9749)})
# Epoch 178 (Time: 1.28s) (loss: {'loss': 0.010480721481144428, 'PSNR': tensor(25.8167)})
# Epoch 179 (Time: 1.27s) (loss: {'loss': 0.00941463466733694, 'PSNR': tensor(26.2826)})
# Epoch 180 (Time: 1.27s) (loss: {'loss': 0.01009294856339693, 'PSNR': tensor(25.9804)})
# Epoch 181 (Time: 1.33s) (loss: {'loss': 0.010493825189769268, 'PSNR': tensor(25.8113)})
# Epoch 182 (Time: 1.27s) (loss: {'loss': 0.00983952172100544, 'PSNR': tensor(26.0909)})
# Epoch 183 (Time: 1.27s) (loss: {'loss': 0.01008924562484026, 'PSNR': tensor(25.9820)})
# Epoch 184 (Time: 1.30s) (loss: {'loss': 0.010267065837979317, 'PSNR': tensor(25.9061)})
# Epoch 185 (Time: 1.29s) (loss: {'loss': 0.009672734886407852, 'PSNR': tensor(26.1651)})
# Epoch 186 (Time: 1.27s) (loss: {'loss': 0.010632326826453209, 'PSNR': tensor(25.7543)})
# Epoch 187 (Time: 1.28s) (loss: {'loss': 0.0100161824375391, 'PSNR': tensor(26.0136)})
# Epoch 188 (Time: 1.29s) (loss: {'loss': 0.009840129874646664, 'PSNR': tensor(26.0906)})
# Epoch 189 (Time: 1.31s) (loss: {'loss': 0.009748533368110657, 'PSNR': tensor(26.1312)})
# Epoch 190 (Time: 1.27s) (loss: {'loss': 0.009881686419248581, 'PSNR': tensor(26.0723)})
# Epoch 191 (Time: 1.28s) (loss: {'loss': 0.01021780539304018, 'PSNR': tensor(25.9270)})
# Epoch 192 (Time: 1.26s) (loss: {'loss': 0.010728978551924229, 'PSNR': tensor(25.7150)})
# Epoch 193 (Time: 1.27s) (loss: {'loss': 0.008999375626444817, 'PSNR': tensor(26.4785)})
# Epoch 194 (Time: 1.30s) (loss: {'loss': 0.009329588152468204, 'PSNR': tensor(26.3220)})
# Epoch 195 (Time: 1.28s) (loss: {'loss': 0.009694966487586498, 'PSNR': tensor(26.1551)})
# Epoch 196 (Time: 1.28s) (loss: {'loss': 0.009112768806517124, 'PSNR': tensor(26.4241)})
# Epoch 197 (Time: 1.26s) (loss: {'loss': 0.009500986896455288, 'PSNR': tensor(26.2429)})
# Epoch 198 (Time: 1.28s) (loss: {'loss': 0.010386946611106396, 'PSNR': tensor(25.8557)})
# Epoch 199 (Time: 1.28s) (loss: {'loss': 0.009978191927075386, 'PSNR': tensor(26.0301)})
# Epoch 200 (Time: 1.29s) (loss: {'loss': 0.009970644488930702, 'PSNR': tensor(26.0334)})
# Finish training for 200 epochs

# %% [markdown]
# ### 效果

# %%
img = []
model = exp1.net.to(device)
titles = ['clean', 'noise', 'DnCNN']

x, clean = test_set[0]
x = x.unsqueeze(0).to(device)
img.append(clean)
img.append(x[0])

model.eval()
with torch.no_grad():
    y = model.forward(x)
img.append(y[0])
    
fig, axes = plt.subplots(ncols=3, figsize=(20,10), sharex='all', sharey='all')
for i in range(len(img)):
    myimshow(img[i], ax=axes[i])
    axes[i].set_title(f'{titles[i]}')

# %%
img = []
model = exp1.net.to(device)
titles = ['clean', 'noise', 'DnCNN']

x, clean = test_set[0]
x = x.unsqueeze(0).to(device)
img.append(clean)
img.append(x[0])

model.eval()
with torch.no_grad():
    y = model.forward(x)
img.append(y[0])
    
fig, axes = plt.subplots(ncols=3, figsize=(20,10), sharex='all', sharey='all')
for i in range(len(img)):
    myimshow(img[i], ax=axes[i])
    axes[i].set_title(f'{titles[i]}')

# %% [markdown]
# 仍存在噪点，有信息缺失

# %% [markdown]
# ### `DnCNN` 网络参数

# %%
for name, param in model.named_parameters():
    print(name, param.size(), param.requires_grad)

# %% [markdown]
# 参数个数
#
# 第一层有 `64 x 3 x 3 x 3` 个 parameter. `D` 层则有 `64 x 64 x 3 x 3 x D`. 最后一层是 `3 x 64 x 3 x 3` . 总共 `3456 + 36864 x D`
#
# 感受野 (Receptive Field) 计算：
#
# 没有池化层，每层固定增加 $2^{0-0+1}=2$，初始输入层是 1 ，小学奥数得到 $R_D=(1+2\times (D+2))^2$.
#
# `D=6` 为例， $R_6=17^2$.

# %% [markdown]
# 据说（待考证）σ = 30 高斯噪声下的降噪，单个像素应受到 33 × 33 个像素影响，据此来确定深度。
#
# 感受野 $R_D=(1+2\times (D+2)) \times (1+2\times (D+2))$， 令等于33 得到 $D=14$，参数个数 $3456 + 36864 \times 14 = 519552$。

# %% [markdown]
# ## 4. UDnCNN
# U-net like CNNs

# %%
class UDnCNN(NNRegressor):

    def __init__(self, D, C=64):
        super(UDnCNN, self).__init__()
        self.D = D
        
        self.conv = nn.ModuleList()
        self.conv.append(nn.Conv2d(3, C, 3, padding=1))
        self.conv.extend([nn.Conv2d(C, C, 3, padding=1) for _ in range(D)])
        self.conv.append(nn.Conv2d(C,3, 3, padding=1))
        # Kaiming正态分布初始化，又叫啥He('s) initialization
        for i in range(len(self.conv[:-1])):
            nn.init.kaiming_normal_(self.conv[i].weight.data, nonlinearity='relu')
        
        # batch norm
        self.bn = nn.ModuleList()
        self.bn.extend([nn.BatchNorm2d(C, C) for _ in range(D)])
        # Batch norm layer 初始化权值
        for i in range(D):
            nn.init.constant_(self.bn[i].weight.data, 1.25 * np.sqrt(C))
    # 前面都一样，这里搞个U-Net
    def forward(self, x):
        D = self.D
        h = F.relu(self.conv[0](x))
        h_buff = []
        idx_buff = []
        shape_buff = []
        for i in range(D//2-1):
            shape_buff.append(h.shape)
            h, idx = F.max_pool2d(F.relu(self.bn[i](self.conv[i+1](h))), 
                                  kernel_size=(2,2), return_indices=True)
            h_buff.append(h)
            idx_buff.append(idx)
        for i in range(D//2-1, D//2+1):
            h = F.relu(self.bn[i](self.conv[i+1](h)))
        for i in range(D//2+1, D):
            j = i - (D//2 + 1) + 1
            h = F.max_unpool2d(F.relu(self.bn[i](self.conv[i+1]((h+h_buff[-j])/np.sqrt(2)))), 
                               idx_buff[-j], kernel_size=(2,2), output_size=shape_buff[-j])
        y = self.conv[D+1](h) + x
        return y

# %% [markdown]
# ### `UDnCNN` 炼丹

# %%
lr = 1e-3
net = UDnCNN(6).to(device)
adam = torch.optim.Adam(net.parameters(), lr=lr)
stats_manager = DenoisingStatsManager()
exp2 = nt.Experiment(net, train_set, test_set, adam, stats_manager, batch_size=10, 
               output_dir="./checkpoints/denoising2", perform_validation_during_training=True)

# %%
fig, axes = plt.subplots(ncols=2, nrows=2, figsize=(9, 7))
exp2.run(num_epochs=300, plot=lambda exp: plot(exp, fig=fig, axes=axes,
                                                noisy=test_set[0][0]))
# Out:
# Start/Continue training from epoch 0
# Epoch 1 (Time: 3.68s)
# Epoch 2 (Time: 2.46s)
# Epoch 3 (Time: 1.91s)
# Epoch 4 (Time: 1.56s)
# Epoch 5 (Time: 1.24s)
# Epoch 6 (Time: 1.21s)
# Epoch 7 (Time: 1.19s)
# Epoch 8 (Time: 1.20s)
# Epoch 9 (Time: 1.13s)
# Epoch 10 (Time: 1.18s)
# Epoch 11 (Time: 1.15s)
# Epoch 12 (Time: 1.07s)
# Epoch 13 (Time: 0.98s)
# Epoch 14 (Time: 1.01s)
# Epoch 15 (Time: 1.03s)
# Epoch 16 (Time: 1.06s)
# Epoch 17 (Time: 1.01s)
# Epoch 18 (Time: 1.01s)
# Epoch 19 (Time: 1.01s)
# Epoch 20 (Time: 0.98s)
# Epoch 21 (Time: 0.99s)
# Epoch 22 (Time: 1.01s)
# Epoch 23 (Time: 1.00s)
# Epoch 24 (Time: 1.00s)
# Epoch 25 (Time: 0.99s)
# Epoch 26 (Time: 1.00s)
# Epoch 27 (Time: 1.01s)
# Epoch 28 (Time: 1.00s)
# Epoch 29 (Time: 1.02s)
# Epoch 30 (Time: 0.98s)
# Epoch 31 (Time: 1.17s)
# Epoch 32 (Time: 1.13s)
# Epoch 33 (Time: 1.09s)
# Epoch 34 (Time: 1.10s)
# Epoch 35 (Time: 1.13s)
# Epoch 36 (Time: 1.11s)
# Epoch 37 (Time: 1.04s)
# Epoch 38 (Time: 1.09s)
# Epoch 39 (Time: 1.04s)
# Epoch 40 (Time: 1.02s)
# Epoch 41 (Time: 1.06s)
# Epoch 42 (Time: 1.06s)
# Epoch 43 (Time: 1.02s)
# Epoch 44 (Time: 1.00s)
# Epoch 45 (Time: 1.01s)
# Epoch 46 (Time: 1.00s)
# Epoch 47 (Time: 1.00s)
# Epoch 48 (Time: 1.03s)
# Epoch 49 (Time: 1.01s)
# Epoch 50 (Time: 1.06s)
# Epoch 51 (Time: 1.00s)
# Epoch 52 (Time: 1.01s)
# Epoch 53 (Time: 1.00s)
# Epoch 54 (Time: 1.00s)
# Epoch 55 (Time: 1.04s)
# Epoch 56 (Time: 0.99s)
# Epoch 57 (Time: 1.08s)
# Epoch 58 (Time: 1.05s)
# Epoch 59 (Time: 1.07s)
# Epoch 60 (Time: 1.05s)
# Epoch 61 (Time: 1.05s)
# Epoch 62 (Time: 1.05s)
# Epoch 63 (Time: 1.05s)
# Epoch 64 (Time: 1.04s)
# Epoch 65 (Time: 1.07s)
# Epoch 66 (Time: 1.06s)
# Epoch 67 (Time: 1.11s)
# Epoch 68 (Time: 1.09s)
# Epoch 69 (Time: 1.12s)
# Epoch 70 (Time: 1.21s)
# Epoch 71 (Time: 1.25s)
# Epoch 72 (Time: 1.26s)
# Epoch 73 (Time: 1.09s)
# Epoch 74 (Time: 1.19s)
# Epoch 75 (Time: 1.22s)
# Epoch 76 (Time: 1.27s)
# Epoch 77 (Time: 1.25s)
# Epoch 78 (Time: 1.31s)
# Epoch 79 (Time: 1.20s)
# Epoch 80 (Time: 1.19s)
# Epoch 81 (Time: 1.19s)
# Epoch 82 (Time: 1.20s)
# Epoch 83 (Time: 1.26s)
# Epoch 84 (Time: 1.21s)
# Epoch 85 (Time: 1.19s)
# Epoch 86 (Time: 1.16s)
# Epoch 87 (Time: 1.17s)
# Epoch 88 (Time: 1.17s)
# Epoch 89 (Time: 1.19s)
# Epoch 90 (Time: 1.20s)
# Epoch 91 (Time: 1.23s)
# Epoch 92 (Time: 1.38s)
# Epoch 93 (Time: 1.25s)
# Epoch 94 (Time: 1.14s)
# Epoch 95 (Time: 1.14s)
# Epoch 96 (Time: 1.09s)
# Epoch 97 (Time: 1.11s)
# Epoch 98 (Time: 1.12s)
# Epoch 99 (Time: 1.11s)
# Epoch 100 (Time: 1.14s)
# Epoch 101 (Time: 1.20s)
# Epoch 102 (Time: 1.22s)
# Epoch 103 (Time: 1.24s)
# Epoch 104 (Time: 1.28s)
# Epoch 105 (Time: 1.28s)
# Epoch 106 (Time: 1.24s)
# Epoch 107 (Time: 1.28s)
# Epoch 108 (Time: 1.23s)
# Epoch 109 (Time: 1.22s)
# Epoch 110 (Time: 1.18s)
# Epoch 111 (Time: 1.22s)
# Epoch 112 (Time: 1.15s)
# Epoch 113 (Time: 1.15s)
# Epoch 114 (Time: 1.16s)
# Epoch 115 (Time: 1.21s)
# Epoch 116 (Time: 1.14s)
# Epoch 117 (Time: 1.12s)
# Epoch 118 (Time: 1.07s)
# Epoch 119 (Time: 1.09s)
# Epoch 120 (Time: 1.04s)
# Epoch 121 (Time: 1.09s)
# Epoch 122 (Time: 1.07s)
# Epoch 123 (Time: 1.11s)
# Epoch 124 (Time: 1.12s)
# Epoch 125 (Time: 1.11s)
# Epoch 126 (Time: 1.15s)
# Epoch 127 (Time: 1.10s)
# Epoch 128 (Time: 1.11s)
# Epoch 129 (Time: 1.10s)
# Epoch 130 (Time: 1.12s)
# Epoch 131 (Time: 1.16s)
# Epoch 132 (Time: 1.10s)
# Epoch 133 (Time: 1.06s)
# Epoch 134 (Time: 1.07s)
# Epoch 135 (Time: 1.07s)
# Epoch 136 (Time: 1.07s)
# Epoch 137 (Time: 1.05s)
# Epoch 138 (Time: 1.10s)
# Epoch 139 (Time: 1.09s)
# Epoch 140 (Time: 1.10s)
# Epoch 141 (Time: 1.06s)
# Epoch 142 (Time: 1.06s)
# Epoch 143 (Time: 1.07s)
# Epoch 144 (Time: 1.05s)
# Epoch 145 (Time: 1.06s)
# Epoch 146 (Time: 1.06s)
# Epoch 147 (Time: 1.18s)
# Epoch 148 (Time: 1.07s)
# Epoch 149 (Time: 1.07s)
# Epoch 150 (Time: 1.09s)
# Epoch 151 (Time: 1.05s)
# Epoch 152 (Time: 1.08s)
# Epoch 153 (Time: 1.09s)
# Epoch 154 (Time: 1.07s)
# Epoch 155 (Time: 1.05s)
# Epoch 156 (Time: 1.10s)
# Epoch 157 (Time: 1.11s)
# Epoch 158 (Time: 1.07s)
# Epoch 159 (Time: 1.11s)
# Epoch 160 (Time: 1.07s)
# Epoch 161 (Time: 1.08s)
# Epoch 162 (Time: 1.14s)
# Epoch 163 (Time: 1.11s)
# Epoch 164 (Time: 1.15s)
# Epoch 165 (Time: 1.10s)
# Epoch 166 (Time: 1.07s)
# Epoch 167 (Time: 1.09s)
# Epoch 168 (Time: 1.07s)
# Epoch 169 (Time: 1.08s)
# Epoch 170 (Time: 1.08s)
# Epoch 171 (Time: 1.07s)
# Epoch 172 (Time: 1.09s)
# Epoch 173 (Time: 1.09s)
# Epoch 174 (Time: 1.09s)
# Epoch 175 (Time: 1.12s)
# Epoch 176 (Time: 1.14s)
# Epoch 177 (Time: 1.14s)
# Epoch 178 (Time: 1.16s)
# Epoch 179 (Time: 1.16s)
# Epoch 180 (Time: 1.08s)
# Epoch 181 (Time: 1.07s)
# Epoch 182 (Time: 1.09s)
# Epoch 183 (Time: 1.10s)
# Epoch 184 (Time: 1.07s)
# Epoch 185 (Time: 1.08s)
# Epoch 186 (Time: 1.10s)
# Epoch 187 (Time: 1.11s)
# Epoch 188 (Time: 1.12s)
# Epoch 189 (Time: 1.20s)
# Epoch 190 (Time: 1.16s)
# Epoch 191 (Time: 1.07s)
# Epoch 192 (Time: 1.07s)
# Epoch 193 (Time: 1.08s)
# Epoch 194 (Time: 1.09s)
# Epoch 195 (Time: 1.12s)
# Epoch 196 (Time: 1.07s)
# Epoch 197 (Time: 1.07s)
# Epoch 198 (Time: 1.07s)
# Epoch 199 (Time: 1.08s)
# Epoch 200 (Time: 1.10s)
# Epoch 201 (Time: 1.09s)
# Epoch 202 (Time: 1.08s)
# Epoch 203 (Time: 1.16s)
# Epoch 204 (Time: 1.13s)
# Epoch 205 (Time: 1.10s)
# Epoch 206 (Time: 1.09s)
# Epoch 207 (Time: 1.11s)
# Epoch 208 (Time: 1.12s)
# Epoch 209 (Time: 1.09s)
# Epoch 210 (Time: 1.06s)
# Epoch 211 (Time: 1.11s)
# Epoch 212 (Time: 1.10s)
# Epoch 213 (Time: 1.10s)
# Epoch 214 (Time: 1.11s)
# Epoch 215 (Time: 1.09s)
# Epoch 216 (Time: 1.06s)
# Epoch 217 (Time: 1.07s)
# Epoch 218 (Time: 1.07s)
# Epoch 219 (Time: 1.13s)
# Epoch 220 (Time: 1.07s)
# Epoch 221 (Time: 1.06s)
# Epoch 222 (Time: 1.07s)
# Epoch 223 (Time: 1.09s)
# Epoch 224 (Time: 1.23s)
# Epoch 225 (Time: 1.11s)
# Epoch 226 (Time: 1.09s)
# Epoch 227 (Time: 1.18s)
# Epoch 228 (Time: 1.07s)
# Epoch 229 (Time: 1.08s)
# Epoch 230 (Time: 1.08s)
# Epoch 231 (Time: 1.10s)
# Epoch 232 (Time: 1.06s)
# Epoch 233 (Time: 1.09s)
# Epoch 234 (Time: 1.07s)
# Epoch 235 (Time: 1.13s)
# Epoch 236 (Time: 1.07s)
# Epoch 237 (Time: 1.08s)
# Epoch 238 (Time: 1.07s)
# Epoch 239 (Time: 1.11s)
# Epoch 240 (Time: 1.14s)
# Epoch 241 (Time: 1.12s)
# Epoch 242 (Time: 1.09s)
# Epoch 243 (Time: 1.09s)
# Epoch 244 (Time: 1.12s)
# Epoch 245 (Time: 1.12s)
# Epoch 246 (Time: 1.15s)
# Epoch 247 (Time: 1.09s)
# Epoch 248 (Time: 1.09s)
# Epoch 249 (Time: 1.11s)
# Epoch 250 (Time: 1.10s)
# Epoch 251 (Time: 1.10s)
# Epoch 252 (Time: 1.13s)
# Epoch 253 (Time: 1.15s)
# Epoch 254 (Time: 1.10s)
# Epoch 255 (Time: 1.11s)
# Epoch 256 (Time: 1.12s)
# Epoch 257 (Time: 1.11s)
# Epoch 258 (Time: 1.11s)
# Epoch 259 (Time: 1.10s)
# Epoch 260 (Time: 1.12s)
# Epoch 261 (Time: 1.16s)
# Epoch 262 (Time: 1.11s)
# Epoch 263 (Time: 1.10s)
# Epoch 264 (Time: 1.11s)
# Epoch 265 (Time: 1.09s)
# Epoch 266 (Time: 1.06s)
# Epoch 267 (Time: 1.06s)
# Epoch 268 (Time: 1.07s)
# Epoch 269 (Time: 1.14s)
# Epoch 270 (Time: 1.08s)
# Epoch 271 (Time: 1.10s)
# Epoch 272 (Time: 1.10s)
# Epoch 273 (Time: 1.11s)
# Epoch 274 (Time: 1.09s)
# Epoch 275 (Time: 1.09s)
# Epoch 276 (Time: 1.06s)
# Epoch 277 (Time: 1.13s)
# Epoch 278 (Time: 1.06s)
# Epoch 279 (Time: 1.07s)
# Epoch 280 (Time: 1.08s)
# Epoch 281 (Time: 1.10s)
# Epoch 282 (Time: 1.05s)
# Epoch 283 (Time: 1.07s)
# Epoch 284 (Time: 1.09s)
# Epoch 285 (Time: 1.15s)
# Epoch 286 (Time: 1.11s)
# Epoch 287 (Time: 1.10s)
# Epoch 288 (Time: 1.15s)
# Epoch 289 (Time: 1.11s)
# Epoch 290 (Time: 1.13s)
# Epoch 291 (Time: 1.10s)
# Epoch 292 (Time: 1.09s)
# Epoch 293 (Time: 1.13s)
# Epoch 294 (Time: 1.09s)
# Epoch 295 (Time: 1.09s)
# Epoch 296 (Time: 1.05s)
# Epoch 297 (Time: 1.05s)
# Epoch 298 (Time: 1.09s)
# Epoch 299 (Time: 1.04s)
# Epoch 300 (Time: 1.06s)
# Finish training for 300 epochs

# %% [markdown]
# ### `UDnCNN` 网络参数

# %%
for name, param in exp2.net.named_parameters():
    print(name, param.size(), param.requires_grad)
# Out:
# conv.0.weight torch.Size([64, 3, 3, 3]) True
# conv.0.bias torch.Size([64]) True
# conv.1.weight torch.Size([64, 64, 3, 3]) True
# conv.1.bias torch.Size([64]) True
# conv.2.weight torch.Size([64, 64, 3, 3]) True
# conv.2.bias torch.Size([64]) True
# conv.3.weight torch.Size([64, 64, 3, 3]) True
# conv.3.bias torch.Size([64]) True
# conv.4.weight torch.Size([64, 64, 3, 3]) True
# conv.4.bias torch.Size([64]) True
# conv.5.weight torch.Size([64, 64, 3, 3]) True
# conv.5.bias torch.Size([64]) True
# conv.6.weight torch.Size([64, 64, 3, 3]) True
# conv.6.bias torch.Size([64]) True
# conv.7.weight torch.Size([3, 64, 3, 3]) True
# conv.7.bias torch.Size([3]) True
# bn.0.weight torch.Size([64]) True
# bn.0.bias torch.Size([64]) True
# bn.1.weight torch.Size([64]) True
# bn.1.bias torch.Size([64]) True
# bn.2.weight torch.Size([64]) True
# bn.2.bias torch.Size([64]) True
# bn.3.weight torch.Size([64]) True
# bn.3.bias torch.Size([64]) True
# bn.4.weight torch.Size([64]) True
# bn.4.bias torch.Size([64]) True
# bn.5.weight torch.Size([64]) True
# bn.5.bias torch.Size([64]) True

# %%
for name, param in exp2.net.named_parameters():
    print(name, param.size(), param.requires_grad)

# %% [markdown]
# 池化不改变参数个数，还是 `3456 + 36864 x D`.
#
# 感受野 (Receptive Field) 计算：
#
# $R_D=(1+\sum_{i=1}^{D/2}2^i+2\times 2^{D/2}+\sum_{i=1}^{D/2-1}2^i+2)^2$.
#
# `D=6` 为例 $R_6(1+(2+4+8)+(2\times 8)+(4+2)+2)^2=39^2$.
#
# 从 PSNR 看，加了 U-Net 更烂了... 池化会丢失价值特征信息，但图上看起来更“好看”了...

# %% [markdown]
# ### 比比 `DnCNN` 和 `UDnCNN`

# %%
# DnCNN
exp1.evaluate()
# Out:
# {'loss': 0.009670600295066833, 'PSNR': tensor(26.1661)}

# %%
# UDnCNN
exp2.evaluate()
# Out:
# {'loss': 0.0077126226387917995, 'PSNR': tensor(27.1486)}

# %%
img = []
titles = ['clean', 'noise', 'DnCNN','UDnCNN']

x, clean = test_set[0]
x = x.unsqueeze(0).to(device)
img.append(clean)
img.append(x[0])

model = exp1.net.to(device)
model.eval()
with torch.no_grad():
    y = model.forward(x)
img.append(y[0])

model = exp2.net.to(device)
model.eval()
with torch.no_grad():
    y = model.forward(x)
img.append(y[0])
    
fig, axes = plt.subplots(ncols=4, figsize=(20,10), sharex='all', sharey='all')
for i in range(len(img)):
    myimshow(img[i], ax=axes[i])
    axes[i].set_title(f'{titles[i]}')

# %% [markdown]
# ## 5. DUDnCNN
# U-net like CNNs with dilated convolutions

# %% [markdown]
# 空洞卷积(dilated convolution)代替池化来增大感受野(Receptive Field)

# %% [markdown]
# 然而 pytorch 空洞卷积跑的贼慢，原理上看应该和普通卷积差不多快，这里有个优化的问题...
#
# 空洞卷积之前
# `torch.backends.cudnn.benchmark=True` 之后改回 `torch.backends.cudnn.benchmark=False` 可以提速，详见 [https://github.com/pytorch/pytorch/issues/15054](https://github.com/pytorch/pytorch/issues/15054).

# %%
class DUDnCNN(NNRegressor):

    def __init__(self, D, C=64):
        super(DUDnCNN, self).__init__()
        self.D = D
        
        # compute k(max_pool) and l(max_unpool)
        k = [0]
        k.extend([i for i in range(D//2)])
        k.extend([k[-1] for _ in range(D//2, D+1)])
        l = [0 for _ in range(D//2+1)]
        l.extend([i for i in range(D+1-(D//2+1))])
        l.append(l[-1])
        
        # 空洞卷积
        holes = [2**(kl[0]-kl[1])-1 for kl in zip(k,l)]
        dilations = [i+1 for i in holes]
        
        # 卷积层
        self.conv = nn.ModuleList()
        self.conv.append(nn.Conv2d(3, C, 3, padding=dilations[0], dilation=dilations[0]))
        self.conv.extend([nn.Conv2d(C, C, 3, padding=dilations[i+1], dilation=dilations[i+1]) for i in range(D)])
        self.conv.append(nn.Conv2d(C, 3, 3, padding=dilations[-1], dilation=dilations[-1]))
        # Kaiming正态分布初始化，又叫啥He('s) initialization
        for i in range(len(self.conv[:-1])):
            nn.init.kaiming_normal_(self.conv[i].weight.data, nonlinearity='relu')
        
        # batch norm
        self.bn = nn.ModuleList()
        self.bn.extend([nn.BatchNorm2d(C, C) for _ in range(D)])
        # Batch norm layer 初始化权值
        for i in range(D):
            nn.init.constant_(self.bn[i].weight.data, 1.25 * np.sqrt(C))

    def forward(self, x):
        D = self.D
        h = F.relu(self.conv[0](x))
        h_buff = []

        for i in range(D//2 - 1):
            torch.backends.cudnn.benchmark = True
            h = self.conv[i+1](h)
            torch.backends.cudnn.benchmark = False
            h = F.relu(self.bn[i](h))
            h_buff.append(h)
            
        for i in range(D//2 - 1, D//2 + 1):
            torch.backends.cudnn.benchmark = True
            h = self.conv[i+1](h)
            torch.backends.cudnn.benchmark = False
            h = F.relu(self.bn[i](h))
            
        for i in range(D//2 + 1, D):
            j = i - (D//2 + 1) + 1
            torch.backends.cudnn.benchmark = True
            h = self.conv[i+1]((h + h_buff[-j]) / np.sqrt(2))
            torch.backends.cudnn.benchmark = False
            h = F.relu(self.bn[i](h))
            
        y = self.conv[D+1](h) + x
        return y
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_34508/438074957.py in <module>
# ----> 1 class DUDnCNN(NNRegressor):
#       2
#       3     def __init__(self, D, C=64):
#       4         super(DUDnCNN, self).__init__()
#       5         self.D = D
#
# NameError: name 'NNRegressor' is not defined

# %% [markdown]
# ### `DUDnCNN` 炼丹

# %%
lr = 1e-3
net = DUDnCNN(6).to(device)
adam = torch.optim.Adam(net.parameters(), lr=lr)
stats_manager = DenoisingStatsManager()
exp3 = nt.Experiment(net, train_set, test_set, adam, stats_manager, batch_size=10, 
               output_dir="./checkpoints/denoising3", perform_validation_during_training=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_34508/2811811037.py in <module>
#       1 lr = 1e-3
# ----> 2 net = DUDnCNN(6).to(device)
#       3 adam = torch.optim.Adam(net.parameters(), lr=lr)
#       4 stats_manager = DenoisingStatsManager()
#       5 exp3 = nt.Experiment(net, train_set, test_set, adam, stats_manager, batch_size=10,
#
# NameError: name 'DUDnCNN' is not defined

# %%
exp3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_34508/1779051817.py in <module>
# ----> 1 exp3
#
# NameError: name 'exp3' is not defined

# %%
fig, axes = plt.subplots(ncols=2, nrows=2, figsize=(9, 7))
exp3.run(num_epochs=300, plot=lambda exp: plot(exp, fig=fig, axes=axes,
                                                noisy=test_set[0][0]))
# Out:
# Start/Continue training from epoch 0
# Epoch 1 (Time: 3.53s)
# Epoch 2 (Time: 2.41s)
# Epoch 3 (Time: 2.16s)
# Epoch 4 (Time: 1.88s)
# Epoch 5 (Time: 3.56s)
# Epoch 6 (Time: 2.59s)
# Epoch 7 (Time: 2.11s)
# Epoch 8 (Time: 1.77s)
# Epoch 9 (Time: 1.46s)
# Epoch 10 (Time: 1.47s)
# Epoch 11 (Time: 1.51s)
# Epoch 12 (Time: 1.52s)
# Epoch 13 (Time: 1.44s)
# Epoch 14 (Time: 1.42s)
# Epoch 15 (Time: 1.43s)
# Epoch 16 (Time: 1.43s)
# Epoch 17 (Time: 1.35s)
# Epoch 18 (Time: 1.34s)
# Epoch 19 (Time: 1.33s)
# Epoch 20 (Time: 1.34s)
# Epoch 21 (Time: 1.32s)
# Epoch 22 (Time: 1.39s)
# Epoch 23 (Time: 1.35s)
# Epoch 24 (Time: 1.30s)
# Epoch 25 (Time: 1.32s)
# Epoch 26 (Time: 1.33s)
# Epoch 27 (Time: 1.32s)
# Epoch 28 (Time: 1.34s)
# Epoch 29 (Time: 1.33s)
# Epoch 30 (Time: 1.32s)
# Epoch 31 (Time: 1.34s)
# Epoch 32 (Time: 1.36s)
# Epoch 33 (Time: 1.33s)
# Epoch 34 (Time: 1.32s)
# Epoch 35 (Time: 1.32s)
# Epoch 36 (Time: 1.33s)
# Epoch 37 (Time: 1.29s)
# Epoch 38 (Time: 1.34s)
# Epoch 39 (Time: 1.33s)
# Epoch 40 (Time: 1.31s)
# Epoch 41 (Time: 1.32s)
# Epoch 42 (Time: 1.33s)
# Epoch 43 (Time: 1.33s)
# Epoch 44 (Time: 1.32s)
# Epoch 45 (Time: 1.31s)
# Epoch 46 (Time: 1.31s)
# Epoch 47 (Time: 1.31s)
# Epoch 48 (Time: 1.33s)
# Epoch 49 (Time: 1.32s)
# Epoch 50 (Time: 1.32s)
# Epoch 51 (Time: 1.32s)
# Epoch 52 (Time: 1.35s)
# Epoch 53 (Time: 1.32s)
# Epoch 54 (Time: 1.33s)
# Epoch 55 (Time: 1.38s)
# Epoch 56 (Time: 1.34s)
# Epoch 57 (Time: 1.48s)
# Epoch 58 (Time: 1.37s)
# Epoch 59 (Time: 1.34s)
# Epoch 60 (Time: 1.35s)
# Epoch 61 (Time: 1.37s)
# Epoch 62 (Time: 1.37s)
# Epoch 63 (Time: 1.40s)
# Epoch 64 (Time: 1.34s)
# Epoch 65 (Time: 1.35s)
# Epoch 66 (Time: 1.48s)
# Epoch 67 (Time: 1.42s)
# Epoch 68 (Time: 1.43s)
# Epoch 69 (Time: 1.43s)
# Epoch 70 (Time: 1.41s)
# Epoch 71 (Time: 1.34s)
# Epoch 72 (Time: 1.38s)
# Epoch 73 (Time: 1.35s)
# Epoch 74 (Time: 1.38s)
# Epoch 75 (Time: 1.56s)
# Epoch 76 (Time: 1.47s)
# Epoch 77 (Time: 1.35s)
# Epoch 78 (Time: 1.37s)
# Epoch 79 (Time: 1.39s)
# Epoch 80 (Time: 1.34s)
# Epoch 81 (Time: 1.35s)
# Epoch 82 (Time: 1.35s)
# Epoch 83 (Time: 1.35s)
# Epoch 84 (Time: 1.37s)
# Epoch 85 (Time: 1.35s)
# Epoch 86 (Time: 1.34s)
# Epoch 87 (Time: 1.42s)
# Epoch 88 (Time: 1.38s)
# Epoch 89 (Time: 1.35s)
# Epoch 90 (Time: 1.36s)
# Epoch 91 (Time: 1.36s)
# Epoch 92 (Time: 1.34s)
# Epoch 93 (Time: 1.35s)
# Epoch 94 (Time: 1.33s)
# Epoch 95 (Time: 1.45s)
# Epoch 96 (Time: 1.38s)
# Epoch 97 (Time: 1.33s)
# Epoch 98 (Time: 1.35s)
# Epoch 99 (Time: 1.36s)
# Epoch 100 (Time: 1.36s)
# Epoch 101 (Time: 1.34s)
# Epoch 102 (Time: 1.36s)
# Epoch 103 (Time: 1.38s)
# Epoch 104 (Time: 1.34s)
# Epoch 105 (Time: 1.34s)
# Epoch 106 (Time: 1.40s)
# Epoch 107 (Time: 1.37s)
# Epoch 108 (Time: 1.34s)
# Epoch 109 (Time: 1.34s)
# Epoch 110 (Time: 1.36s)
# Epoch 111 (Time: 1.36s)
# Epoch 112 (Time: 1.34s)
# Epoch 113 (Time: 1.34s)
# Epoch 114 (Time: 1.58s)
# Epoch 115 (Time: 2.07s)
# Epoch 116 (Time: 1.67s)
# Epoch 117 (Time: 1.37s)
# Epoch 118 (Time: 1.38s)
# Epoch 119 (Time: 1.39s)
# Epoch 120 (Time: 1.38s)
# Epoch 121 (Time: 1.41s)
# Epoch 122 (Time: 1.37s)
# Epoch 123 (Time: 1.34s)
# Epoch 124 (Time: 1.35s)
# Epoch 125 (Time: 1.36s)
# Epoch 126 (Time: 1.35s)
# Epoch 127 (Time: 1.37s)
# Epoch 128 (Time: 1.35s)
# Epoch 129 (Time: 1.34s)
# Epoch 130 (Time: 1.35s)
# Epoch 131 (Time: 1.34s)
# Epoch 132 (Time: 1.34s)
# Epoch 133 (Time: 1.41s)
# Epoch 134 (Time: 1.47s)
# Epoch 135 (Time: 1.41s)
# Epoch 136 (Time: 1.39s)
# Epoch 137 (Time: 1.40s)
# Epoch 138 (Time: 1.36s)
# Epoch 139 (Time: 1.39s)
# Epoch 140 (Time: 1.43s)
# Epoch 141 (Time: 1.38s)
# Epoch 142 (Time: 1.34s)
# Epoch 143 (Time: 1.35s)
# Epoch 144 (Time: 1.36s)
# Epoch 145 (Time: 1.34s)
# Epoch 146 (Time: 1.40s)
# Epoch 147 (Time: 1.35s)
# Epoch 148 (Time: 1.37s)
# Epoch 149 (Time: 1.36s)
# Epoch 150 (Time: 1.35s)
# Epoch 151 (Time: 1.37s)
# Epoch 152 (Time: 1.34s)
# Epoch 153 (Time: 1.40s)
# Epoch 154 (Time: 1.37s)
# Epoch 155 (Time: 1.36s)
# Epoch 156 (Time: 1.34s)
# Epoch 157 (Time: 1.37s)
# Epoch 158 (Time: 1.36s)
# Epoch 159 (Time: 1.36s)
# Epoch 160 (Time: 1.35s)
# Epoch 161 (Time: 1.36s)
# Epoch 162 (Time: 1.35s)
# Epoch 163 (Time: 1.35s)
# Epoch 164 (Time: 1.35s)
# Epoch 165 (Time: 1.35s)
# Epoch 166 (Time: 1.36s)
# Epoch 167 (Time: 1.35s)
# Epoch 168 (Time: 1.35s)
# Epoch 169 (Time: 1.39s)
# Epoch 170 (Time: 1.43s)
# Epoch 171 (Time: 1.45s)
# Epoch 172 (Time: 1.44s)
# Epoch 173 (Time: 1.42s)
# Epoch 174 (Time: 1.44s)
# Epoch 175 (Time: 1.43s)
# Epoch 176 (Time: 1.42s)
# Epoch 177 (Time: 1.42s)
# Epoch 178 (Time: 1.43s)
# Epoch 179 (Time: 1.42s)
# Epoch 180 (Time: 1.35s)
# Epoch 181 (Time: 1.36s)
# Epoch 182 (Time: 1.34s)
# Epoch 183 (Time: 1.34s)
# Epoch 184 (Time: 1.36s)
# Epoch 185 (Time: 1.35s)
# Epoch 186 (Time: 1.35s)
# Epoch 187 (Time: 1.43s)
# Epoch 188 (Time: 1.37s)
# Epoch 189 (Time: 1.35s)
# Epoch 190 (Time: 1.34s)
# Epoch 191 (Time: 1.36s)
# Epoch 192 (Time: 1.35s)
# Epoch 193 (Time: 1.40s)
# Epoch 194 (Time: 1.50s)
# Epoch 195 (Time: 1.39s)
# Epoch 196 (Time: 1.35s)
# Epoch 197 (Time: 1.32s)
# Epoch 198 (Time: 1.33s)
# Epoch 199 (Time: 1.34s)
# Epoch 200 (Time: 1.34s)
# Epoch 201 (Time: 1.35s)
# Epoch 202 (Time: 1.36s)
# Epoch 203 (Time: 1.36s)
# Epoch 204 (Time: 1.34s)
# Epoch 205 (Time: 1.39s)
# Epoch 206 (Time: 1.36s)
# Epoch 207 (Time: 1.37s)
# Epoch 208 (Time: 1.40s)
# Epoch 209 (Time: 1.36s)
# Epoch 210 (Time: 1.39s)
# Epoch 211 (Time: 1.36s)
# Epoch 212 (Time: 1.38s)
# Epoch 213 (Time: 1.42s)
# Epoch 214 (Time: 1.36s)
# Epoch 215 (Time: 1.39s)
# Epoch 216 (Time: 1.39s)
# Epoch 217 (Time: 1.37s)
# Epoch 218 (Time: 1.39s)
# Epoch 219 (Time: 1.40s)
# Epoch 220 (Time: 1.38s)
# Epoch 221 (Time: 1.34s)
# Epoch 222 (Time: 1.41s)
# Epoch 223 (Time: 1.37s)
# Epoch 224 (Time: 1.42s)
# Epoch 225 (Time: 1.41s)
# Epoch 226 (Time: 1.38s)
# Epoch 227 (Time: 1.37s)
# Epoch 228 (Time: 1.41s)
# Epoch 229 (Time: 1.42s)
# Epoch 230 (Time: 1.49s)
# Epoch 231 (Time: 1.49s)
# Epoch 232 (Time: 1.61s)
# Epoch 233 (Time: 2.01s)
# Epoch 234 (Time: 1.68s)
# Epoch 235 (Time: 1.50s)
# Epoch 236 (Time: 1.49s)
# Epoch 237 (Time: 1.46s)
# Epoch 238 (Time: 1.46s)
# Epoch 239 (Time: 1.50s)
# Epoch 240 (Time: 1.47s)
# Epoch 241 (Time: 1.44s)
# Epoch 242 (Time: 1.45s)
# Epoch 243 (Time: 1.40s)
# Epoch 244 (Time: 1.38s)
# Epoch 245 (Time: 1.37s)
# Epoch 246 (Time: 1.39s)
# Epoch 247 (Time: 1.43s)
# Epoch 248 (Time: 1.39s)
# Epoch 249 (Time: 1.39s)
# Epoch 250 (Time: 1.37s)
# Epoch 251 (Time: 1.40s)
# Epoch 252 (Time: 1.38s)
# Epoch 253 (Time: 1.38s)
# Epoch 254 (Time: 1.40s)
# Epoch 255 (Time: 1.44s)
# Epoch 256 (Time: 1.39s)
# Epoch 257 (Time: 1.41s)
# Epoch 258 (Time: 1.40s)
# Epoch 259 (Time: 1.34s)
# Epoch 260 (Time: 1.37s)
# Epoch 261 (Time: 1.49s)
# Epoch 262 (Time: 1.49s)
# Epoch 263 (Time: 1.35s)
# Epoch 264 (Time: 1.43s)
# Epoch 265 (Time: 1.34s)
# Epoch 266 (Time: 1.40s)
# Epoch 267 (Time: 1.36s)
# Epoch 268 (Time: 1.36s)
# Epoch 269 (Time: 1.37s)
# Epoch 270 (Time: 1.39s)
# Epoch 271 (Time: 1.60s)
# Epoch 272 (Time: 1.99s)
# Epoch 273 (Time: 1.68s)
# Epoch 274 (Time: 1.52s)
# Epoch 275 (Time: 1.57s)
# Epoch 276 (Time: 1.51s)
# Epoch 277 (Time: 1.47s)
# Epoch 278 (Time: 1.46s)
# Epoch 279 (Time: 1.46s)
# Epoch 280 (Time: 1.46s)
# Epoch 281 (Time: 1.41s)
# Epoch 282 (Time: 1.40s)
# Epoch 283 (Time: 1.37s)
# Epoch 284 (Time: 1.37s)
# Epoch 285 (Time: 1.37s)
# Epoch 286 (Time: 1.39s)
# Epoch 287 (Time: 1.38s)
# Epoch 288 (Time: 1.38s)
# Epoch 289 (Time: 1.39s)
# Epoch 290 (Time: 1.40s)
# Epoch 291 (Time: 1.40s)
# Epoch 292 (Time: 1.49s)
# Epoch 293 (Time: 1.37s)
# Epoch 294 (Time: 1.45s)
# Epoch 295 (Time: 1.39s)
# Epoch 296 (Time: 1.39s)
# Epoch 297 (Time: 1.44s)
# Epoch 298 (Time: 1.36s)
# Epoch 299 (Time: 1.38s)
# Epoch 300 (Time: 1.46s)
# Finish training for 300 epochs

# %% [markdown]
# ### 比较 `DnCNN` `UDnCNN` `DUDnCNN`

# %%
# DnCNN
exp1.evaluate()
# Out:
# {'loss': 0.009670600295066833, 'PSNR': tensor(26.1661)}

# %%
# UDnCNN
exp2.evaluate()
# Out:
# {'loss': 0.0077126226387917995, 'PSNR': tensor(27.1486)}

# %%
# DUDnCNN
exp3.evaluate()
# Out:
# {'loss': 0.001028584549203515, 'PSNR': tensor(35.8982)}

# %%
num = 2
img = []
nets = [exp1.net, exp2.net, exp3.net]
titles = ['noise','DnCNN', 'UDnCNN', 'DUDnCNN']

fig, axes = plt.subplots(nrows=num, ncols=4, figsize=(20,15), sharex='all', sharey='all')

for i in range(num):
    myimshow(test_set[7*i+7][0], ax=axes[i][0])
    x, _ = test_set[7*i+7]
    x = x.unsqueeze(0).to(device)
    img.append(x)

for i in range(num):
    for j in range(len(nets)):
        
        model = nets[j].to(device)
        model.eval()
        with torch.no_grad():
            y = model.forward(img[i])
        myimshow(y[0], ax=axes[i][j+1])
for i in range(num):
    for j in range(len(titles)):
        axes[i][j].set_title(f'{titles[j]}')

# %% [markdown]
# ### `DUDnCNN` 网络参数

# %%
exp3.net
# Out:
# DUDnCNN(
#   (mse): MSELoss()
#   (conv): ModuleList(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2))
#     (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(4, 4), dilation=(4, 4))
#     (4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(4, 4), dilation=(4, 4))
#     (5): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2))
#     (6): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): Conv2d(64, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (bn): ModuleList(
#     (0): BatchNorm2d(64, eps=64, momentum=0.1, affine=True, track_running_stats=True)
#     (1): BatchNorm2d(64, eps=64, momentum=0.1, affine=True, track_running_stats=True)
#     (2): BatchNorm2d(64, eps=64, momentum=0.1, affine=True, track_running_stats=True)
#     (3): BatchNorm2d(64, eps=64, momentum=0.1, affine=True, track_running_stats=True)
#     (4): BatchNorm2d(64, eps=64, momentum=0.1, affine=True, track_running_stats=True)
#     (5): BatchNorm2d(64, eps=64, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )

# %%
for name, param in exp3.net.named_parameters():
    print(name, param.size(), param.requires_grad)
# Out:
# conv.0.weight torch.Size([64, 3, 3, 3]) True
# conv.0.bias torch.Size([64]) True
# conv.1.weight torch.Size([64, 64, 3, 3]) True
# conv.1.bias torch.Size([64]) True
# conv.2.weight torch.Size([64, 64, 3, 3]) True
# conv.2.bias torch.Size([64]) True
# conv.3.weight torch.Size([64, 64, 3, 3]) True
# conv.3.bias torch.Size([64]) True
# conv.4.weight torch.Size([64, 64, 3, 3]) True
# conv.4.bias torch.Size([64]) True
# conv.5.weight torch.Size([64, 64, 3, 3]) True
# conv.5.bias torch.Size([64]) True
# conv.6.weight torch.Size([64, 64, 3, 3]) True
# conv.6.bias torch.Size([64]) True
# conv.7.weight torch.Size([3, 64, 3, 3]) True
# conv.7.bias torch.Size([3]) True
# bn.0.weight torch.Size([64]) True
# bn.0.bias torch.Size([64]) True
# bn.1.weight torch.Size([64]) True
# bn.1.bias torch.Size([64]) True
# bn.2.weight torch.Size([64]) True
# bn.2.bias torch.Size([64]) True
# bn.3.weight torch.Size([64]) True
# bn.3.bias torch.Size([64]) True
# bn.4.weight torch.Size([64]) True
# bn.4.bias torch.Size([64]) True
# bn.5.weight torch.Size([64]) True
# bn.5.bias torch.Size([64]) True

# %% [markdown]
# 参数个数还是不变 `3456 + 36864 x D`
#
# 感受野 (Receptive Field) 计算：
#
# $R_D=(1+2+\sum_{i=1}^{D/2}2^i\times 2^{i-1}+2^{D/2}\times 2^{D/2-1}+\sum_{i=1}^{D/2-1}2^i\times 2^{i-1}+2)^2$.
#
# $R_6=89^2$.

# %% [markdown]
# ## 6. 输出结果

# %%
import os
# net为网络模型， count为第几张图片， x 为图片的tensor格式3*40*50
def myImageSave(net , count, x):
    image = x
    image = image.to('cpu').numpy()
    image = np.moveaxis(image, [0, 1, 2], [2, 0, 1])
    image = (image + 1) / 2
    image[image < 0] = 0
    image[image > 1] = 1
    im = Image.fromarray((image * 255).astype(np.uint8))
    path = "C:/Users/bbfss/Desktop/Code/github/Denoising-CNN/dataset/结果集/" + net + "/" + str(count) + ".bmp"
    im.save(path)   
    return

# %%
# model表示对应模型, net表示网络名字, count对应相应的图像的编号
# def myFeatureImageSave(model, net, count):
#     for i in range(len(model.features)):
#         net1 = net + "特征层" + str((i+1)*5)
#         path = "C:/Users/bbfss/Desktop/Code/github/Denoising-CNN/dataset/结果集/" + net1 
#         if not os.path.exists(path):
#             os.makedirs(path) 
#         myImageSave(net1, count, model.features[i][0])
#     return

# %%
x, clean = test_set[0]
myImageSave("干净图像结果集", 1, clean)

# %%
count = 0
for test_set_iter in test_set:
    x, clean = test_set_iter
    count += 1 # 给结果图像编号
    x = x.unsqueeze(0).to(device) # 3*40*50 -> 1*3*40*50
    myImageSave("干净图像结果集", count ,clean)
    myImageSave("加噪图像结果集", count ,x[0])

    model = exp1.net.to(device)
    model.eval()
    with torch.no_grad():
        y = model.forward(x)
    myImageSave("DnCNN结果集", count , y[0])
    myFeatureImageSave(model, "DnCNN结果集", count)
    # img.append(y[0])

    model = exp2.net.to(device)
    model.eval()
    with torch.no_grad():
        y = model.forward(x)
    myImageSave("UDnCNN结果集", count , y[0])
    # img.append(y[0])

    model = exp3.net.to(device)
    model.eval()
    with torch.no_grad():
        y = model.forward(x)
    myImageSave("DUDnCNN结果集", count , y[0])
    # img.append(y[0])

# %% [markdown]
# ## 7. 提取中间特征图

# %%
def GetFeature()
